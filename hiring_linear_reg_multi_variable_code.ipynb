# %%
import pandas as pd
import numpy as np
from sklearn import linear_model

# %%
df = pd.read_csv("hiring_linear_reg_multi_variable_data.csv")
df
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0        NaN                    8.0                           9      50000
# 1        NaN                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    NaN                           7      72000
# 7     eleven                    7.0                           8      80000

# %% [markdown]
# <h1> Changes in the Code </h1>
# 1. importing math module <br>
# 2. variable floor_merdian is used to make merdian value into integer <br>
# 3. df["test_score(out of 10)"].median()  is a to get median using median() function<br>

# %%
import math 
floor_median =math.floor( df["test_score(out of 10)"].median())
floor_median
# Out:
# 8

# %% [markdown]
# <h1> Changes in the Code </h1>
# 1.df['test_score(out of 10)']  is a series(column)that is selected<br>
# 2.fillna()  is a function used for filling the empty spaces in the series/column<br>
# 3.floor_merdian is used in the function to fill its value<br>

# %%
df['test_score(out of 10)'].fillna(floor_median)
# Out:
# 0     8.0
# 1     8.0
# 2     6.0
# 3    10.0
# 4     9.0
# 5     7.0
# 6     8.0
# 7     7.0
# Name: test_score(out of 10), dtype: float64

# %% [markdown]
# <h1> Code </h1>
# the changes are now permanently implimented in the Dataframe using <b>df['test_score(out of 10)']</b><br><br>
# <h>  note - This is the part of Cleaning Data <br>
# Cleaning and Preprocesssing Data is very important </h>

# %%
df['test_score(out of 10)'] = df['test_score(out of 10)'].fillna(floor_median)
df
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0        nan                    8.0                           9      50000
# 1        nan                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    8.0                           7      72000
# 7     eleven                    7.0                           8      80000

# %% [markdown]
# Similarly cleaning the other Given Data

# %% [markdown]
# Installing word2number<br>
# it converts word into integer

# %%
from word2number import w2n
import pandas as pd
import numpy as np

def safe_word_to_num(x):
    if pd.isna(x):
        return np.nan      # Keep NaN as it is
    return w2n.word_to_num(x)

df['experience'] = df['experience'].apply(safe_word_to_num)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 10
#       7         return np.nan      # Keep NaN as it is
#       8     return w2n.word_to_num(x)
# ---> 10 df['experience'] = df['experience'].apply(safe_word_to_num)
#
# File c:\Users\Kiran Shinde\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\series.py:4943, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4808 def apply(
#    4809     self,
#    4810     func: AggFuncType,
#    (...)   4815     **kwargs,
#    4816 ) -> DataFrame | Series:
#    4817     """
#    4818     Invoke function on values of Series.
#    4819
#    (...)   4934     dtype: float64
#    4935     """
#    4936     return SeriesApply(
#    4937         self,
#    4938         func,
#    4939         convert_dtype=convert_dtype,
#    4940         by_row=by_row,
#    4941         args=args,
# ...

# %%
df['experience'].median()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 df['experience'].median()
#
# File c:\Users\Kiran Shinde\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\series.py:6580, in Series.median(self, axis, skipna, numeric_only, **kwargs)
#    6572 @doc(make_doc("median", ndim=1))
#    6573 def median(
#    6574     self,
#    (...)   6578     **kwargs,
#    6579 ):
# -> 6580     return NDFrame.median(self, axis, skipna, numeric_only, **kwargs)
#
# File c:\Users\Kiran Shinde\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py:12496, in NDFrame.median(self, axis, skipna, numeric_only, **kwargs)
#   12489 def median(
#   12490     self,
#   12491     axis: Axis | None = 0,
#    (...)  12494     **kwargs,
#   12495 ) -> Series | float:
# > 12496     return self._stat_function(
# ...
